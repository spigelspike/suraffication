# %% [markdown]
# # py-surrafication Demo
#
# This notebook demonstrates the different presets available in `py-surrafication`.

# %%
import os
from IPython.display import Video

# Ensure example images exist
if not os.path.exists("examples/demo_source.jpg"):
    print("Please run the setup first or provide images.")

# %% [markdown]
# ## 1. Sand Preset
# High resolution (128x128), sorted assignment, small circular particles, color mixing.

# %%
# !python -m py_surrafication --src examples/demo_source.jpg --tgt examples/sura.jpg --out demo_sand.mp4 --preset sand

# %%
Video("demo_sand.mp4")

# %% [markdown]
# ## 2. Blocks Preset
# Low resolution (32x32), optimal assignment, square blocks, no color mixing.

# %%
# !python -m py_surrafication --src examples/demo_source.jpg --tgt examples/sura.jpg --out demo_blocks.mp4 --preset blocks

# %%
Video("demo_blocks.mp4")

# %% [markdown]
# ## 3. Bubbles Preset
# Medium resolution (64x64), greedy assignment, large circular bubbles.

# %%
# !python -m py_surrafication --src examples/demo_source.jpg --tgt examples/sura.jpg --out demo_bubbles.mp4 --preset bubbles

# %%
Video("demo_bubbles.mp4")
